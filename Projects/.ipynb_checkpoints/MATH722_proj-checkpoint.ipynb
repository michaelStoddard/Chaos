# %%
import numpy as np

# %% [markdown]
# # Van der Pol

# %%
import sympy as smp

# %% [markdown]
# ## Symbolic solution

# %%
x1, x2, mu, w, t, alp, F= smp.symbols(r'x_1 x_2 \mu \omega t \alpha \mathcal{F}')

# sin = (w*t) - (w*t)**3/(3*2) #+ (w*t)**5/(5*4*3*2) - (w*t)**7/(7*6*5*4*3*2) 

w = 1.2
alp = 0
mu = 1


dx1 = x2
dx2 = -x1 + mu*x2*(1-x1**2) + alp*smp.sin(w*t)
dt = 1

# %% [markdown]
# ### Jacobian about origin

# %%
Jac = smp.Matrix([[smp.diff(dx1,x1),smp.diff(dx1,x2),smp.diff(dx1,t)],
                  [smp.diff(dx2,x1),smp.diff(dx2,x2),smp.diff(dx2,t)],
                  [smp.diff(dt,x1),smp.diff(dt,x2),smp.diff(dt,t)]])
Jac
# Out:
# Matrix([
# [             0,          1, 0],
# [-2*x_1*x_2 - 1, 1 - x_1**2, 0],
# [             0,          0, 0]])

# %%
J0 = Jac.subs([[x1,0],[x2,0],[mu,1]])
J0
# Out:
# Matrix([
# [ 0, 1, 0],
# [-1, 1, 0],
# [ 0, 0, 0]])

# %%
J0.eigenvects()
# Out:
# [(0,
#   1,
#   [Matrix([
#    [0],
#    [0],
#    [1]])]),
#  (1/2 - sqrt(3)*I/2,
#   1,
#   [Matrix([
#    [1/2 + sqrt(3)*I/2],
#    [                1],
#    [                0]])]),
#  (1/2 + sqrt(3)*I/2,
#   1,
#   [Matrix([
#    [1/2 - sqrt(3)*I/2],
#    [                1],
#    [                0]])])]

# %%
J0.eigenvals()
# Out:
# {1/2 - sqrt(3)*I/2: 1, 1/2 + sqrt(3)*I/2: 1, 0: 1}

# %% [markdown]
# ### Transform

# %%
ev1 = J0.eigenvects()[0][2][0]
ev2 = J0.eigenvects()[1][2][0]
ev3 = J0.eigenvects()[2][2][0]
ev1
# Out:
# Matrix([
# [-\alpha*\omega**3*t**2/2 + \alpha*\omega],
# [                                       0],
# [                                       1]])

# %%
P = smp.Matrix([[ev1.T],
               [ev2.T],
               [ev3.T]]).T
P
# Out:
# Matrix([
# [-\alpha*\omega**3*t**2/2 + \alpha*\omega, 1/2 + sqrt(3)*I/2, 1/2 - sqrt(3)*I/2],
# [                                       0,                 1,                 1],
# [                                       1,                 0,                 0]])

# %%
c, s, u = smp.symbols('c s u')

P_inv = P.inv()
csu = smp.Matrix([c,s,u])
xyt_dot = smp.Matrix([dx1,dx2,dt])

# %%
trans = P@csu
trans
# Out:
# Matrix([
# [c*(-\alpha*\omega**3*t**2/2 + \alpha*\omega) + s*(1/2 + sqrt(3)*I/2) + u*(1/2 - sqrt(3)*I/2)],
# [                                                                                       s + u],
# [                                                                                           c]])

# %%
csu_dot = P_inv@xyt_dot
csu_dot
# Out:
# Matrix([
# [                                                                                                                                                                          1],
# [-sqrt(3)*I*\alpha*\omega**3*t**2/6 + sqrt(3)*I*\alpha*\omega/3 - sqrt(3)*I*x_2/3 + (1/2 + sqrt(3)*I/6)*(\alpha*(-\omega**3*t**3/6 + \omega*t) + \mu*x_2*(1 - x_1**2) - x_1)],
# [ sqrt(3)*I*\alpha*\omega**3*t**2/6 - sqrt(3)*I*\alpha*\omega/3 + sqrt(3)*I*x_2/3 + (1/2 - sqrt(3)*I/6)*(\alpha*(-\omega**3*t**3/6 + \omega*t) + \mu*x_2*(1 - x_1**2) - x_1)]])

# %%
csu_dot = csu_dot.subs([[x1,trans[0]],
                       [x2,trans[1]],
                       [t,trans[2]]])

# %% [markdown]
# ### Manifold

# %%
dc = csu_dot[0].expand()
ds = csu_dot[1].expand()
du = csu_dot[2].expand()

# %%
A = dc.coeff(c,1).coeff(s,0).coeff(u,0).coeff(alp,0)
A
# Out:
# 0

# %%
g1 = dc - A*c
g1
# Out:
# 1

# %%
b1 = ds.coeff(c,0).coeff(s,1).coeff(u,0).coeff(alp,0)
b2 = du.coeff(c,0).coeff(s,0).coeff(u,1).coeff(alp,0)

B = smp.Matrix([[b1,0],
                [0,b2]])
B
# Out:
# Matrix([
# [\mu/2 + sqrt(3)*I*\mu/6 - 2*sqrt(3)*I/3,                                       0],
# [                                      0, \mu/2 - sqrt(3)*I*\mu/6 + 2*sqrt(3)*I/3]])

# %%
g2_1 = ds - b1*s
g2_2 = du - b2*u
g2 = smp.Matrix([g2_1,g2_2])
g2
# Out:
# Matrix([
# [-\alpha**2*\mu*\omega**6*c**6*s/8 - sqrt(3)*I*\alpha**2*\mu*\omega**6*c**6*s/24 - \alpha**2*\mu*\omega**6*c**6*u/8 - sqrt(3)*I*\alpha**2*\mu*\omega**6*c**6*u/24 + \alpha**2*\mu*\omega**4*c**4*s/2 + sqrt(3)*I*\alpha**2*\mu*\omega**4*c**4*s/6 + \alpha**2*\mu*\omega**4*c**4*u/2 + sqrt(3)*I*\alpha**2*\mu*\omega**4*c**4*u/6 - \alpha**2*\mu*\omega**2*c**2*s/2 - sqrt(3)*I*\alpha**2*\mu*\omega**2*c**2*s/6 - \alpha**2*\mu*\omega**2*c**2*u/2 - sqrt(3)*I*\alpha**2*\mu*\omega**2*c**2*u/6 + sqrt(3)*I*\alpha*\mu*\omega**3*c**3*s**2/3 + \alpha*\mu*\omega**3*c**3*s*u/2 + sqrt(3)*I*\alpha*\mu*\omega**3*c**3*s*u/6 + \alpha*\mu*\omega**3*c**3*u**2/2 - sqrt(3)*I*\alpha*\mu*\omega**3*c**3*u**2/6 - 2*sqrt(3)*I*\alpha*\mu*\omega*c*s**2/3 - \alpha*\mu*\omega*c*s*u - sqrt(3)*I*\alpha*\mu*\omega*c*s*u/3 - \alpha*\mu*\omega*c*u**2 + sqrt(3)*I*\alpha*\mu*\omega*c*u**2/3 + \alpha*\omega**3*c**3/6 + sqrt(3)*I*\alpha*\omega**3*c**3/18 - sqrt(3)*I*\alpha*\omega**3*c**2/6 + sqrt(3)*I*\alpha*\omega/3 + \mu*s**3/2 - sqrt(3)*I*\mu*s**3/6 - \mu*s**2*u/2 - sqrt(3)*I*\mu*s**2*u/2 - \mu*s*u**2 + \mu*s/2 + sqrt(3)*I*\mu*s/6 + sqrt(3)*I*\mu*u**3/3 + \mu*u/2 + sqrt(3)*I*\mu*u/6 - s*(\mu/2 + sqrt(3)*I*\mu/6 - 2*sqrt(3)*I/3) - 2*sqrt(3)*I*s/3 - u/2 - sqrt(3)*I*u/6],
# [-\alpha**2*\mu*\omega**6*c**6*s/8 + sqrt(3)*I*\alpha**2*\mu*\omega**6*c**6*s/24 - \alpha**2*\mu*\omega**6*c**6*u/8 + sqrt(3)*I*\alpha**2*\mu*\omega**6*c**6*u/24 + \alpha**2*\mu*\omega**4*c**4*s/2 - sqrt(3)*I*\alpha**2*\mu*\omega**4*c**4*s/6 + \alpha**2*\mu*\omega**4*c**4*u/2 - sqrt(3)*I*\alpha**2*\mu*\omega**4*c**4*u/6 - \alpha**2*\mu*\omega**2*c**2*s/2 + sqrt(3)*I*\alpha**2*\mu*\omega**2*c**2*s/6 - \alpha**2*\mu*\omega**2*c**2*u/2 + sqrt(3)*I*\alpha**2*\mu*\omega**2*c**2*u/6 + \alpha*\mu*\omega**3*c**3*s**2/2 + sqrt(3)*I*\alpha*\mu*\omega**3*c**3*s**2/6 + \alpha*\mu*\omega**3*c**3*s*u/2 - sqrt(3)*I*\alpha*\mu*\omega**3*c**3*s*u/6 - sqrt(3)*I*\alpha*\mu*\omega**3*c**3*u**2/3 - \alpha*\mu*\omega*c*s**2 - sqrt(3)*I*\alpha*\mu*\omega*c*s**2/3 - \alpha*\mu*\omega*c*s*u + sqrt(3)*I*\alpha*\mu*\omega*c*s*u/3 + 2*sqrt(3)*I*\alpha*\mu*\omega*c*u**2/3 + \alpha*\omega**3*c**3/6 - sqrt(3)*I*\alpha*\omega**3*c**3/18 + sqrt(3)*I*\alpha*\omega**3*c**2/6 - sqrt(3)*I*\alpha*\omega/3 - sqrt(3)*I*\mu*s**3/3 - \mu*s**2*u - \mu*s*u**2/2 + sqrt(3)*I*\mu*s*u**2/2 + \mu*s/2 - sqrt(3)*I*\mu*s/6 + \mu*u**3/2 + sqrt(3)*I*\mu*u**3/6 + \mu*u/2 - sqrt(3)*I*\mu*u/6 - s/2 + sqrt(3)*I*s/6 - u*(\mu/2 - sqrt(3)*I*\mu/6 + 2*sqrt(3)*I/3) + 2*sqrt(3)*I*u/3]])

# %%
k1, k2, k3, b1, b2, b3 = smp.symbols(r'\kappa_1 \kappa_2 \kappa_3 \beta_1 \beta_2 \beta_3')

h1 = k1*c**2 + k2*c*alp + k3*alp**2
h2 = b1*c**2 + b2*c*alp + b3*alp**2

H = smp.Matrix([h1,h2])
Dh = smp.diff(H,c)

# %%
N = Dh*(A*c + g1) - B@H - g2
N = N.subs([[s,h1],[u,h2]]).expand()
N
# Out:
# Matrix([
# [-sqrt(3)*I*\alpha**6*\beta_3**3*\mu/3 + \alpha**6*\beta_3**2*\kappa_3*\mu + \alpha**6*\beta_3*\kappa_3**2*\mu/2 + sqrt(3)*I*\alpha**6*\beta_3*\kappa_3**2*\mu/2 - \alpha**6*\kappa_3**3*\mu/2 + sqrt(3)*I*\alpha**6*\kappa_3**3*\mu/6 - sqrt(3)*I*\alpha**5*\beta_2*\beta_3**2*\mu*c + 2*\alpha**5*\beta_2*\beta_3*\kappa_3*\mu*c + \alpha**5*\beta_2*\kappa_3**2*\mu*c/2 + sqrt(3)*I*\alpha**5*\beta_2*\kappa_3**2*\mu*c/2 + \alpha**5*\beta_3**2*\kappa_2*\mu*c - \alpha**5*\beta_3**2*\mu*\omega**3*c**3/2 + sqrt(3)*I*\alpha**5*\beta_3**2*\mu*\omega**3*c**3/6 + \alpha**5*\beta_3**2*\mu*\omega*c - sqrt(3)*I*\alpha**5*\beta_3**2*\mu*\omega*c/3 + \alpha**5*\beta_3*\kappa_2*\kappa_3*\mu*c + sqrt(3)*I*\alpha**5*\beta_3*\kappa_2*\kappa_3*\mu*c - \alpha**5*\beta_3*\kappa_3*\mu*\omega**3*c**3/2 - sqrt(3)*I*\alpha**5*\beta_3*\kappa_3*\mu*\omega**3*c**3/6 + \alpha**5*\beta_3*\kappa_3*\mu*\omega*c + sqrt(3)*I*\alpha**5*\beta_3*\kappa_3*\mu*\omega*c/3 - 3*\alpha**5*\kappa_2*\kappa_3**2*\mu*c/2 + sqrt(3)*I*\alpha**5*\kappa_2*\kappa_3**2*\mu*c/2 - sqrt(3)*I*\alpha**5*\kappa_3**2*\mu*\omega**3*c**3/3 + 2*sqrt(3)*I*\alpha**5*\kappa_3**2*\mu*\omega*c/3 - sqrt(3)*I*\alpha**4*\beta_1*\beta_3**2*\mu*c**2 + 2*\alpha**4*\beta_1*\beta_3*\kappa_3*\mu*c**2 + \alpha**4*\beta_1*\kappa_3**2*\mu*c**2/2 + sqrt(3)*I*\alpha**4*\beta_1*\kappa_3**2*\mu*c**2/2 - sqrt(3)*I*\alpha**4*\beta_2**2*\beta_3*\mu*c**2 + \alpha**4*\beta_2**2*\kappa_3*\mu*c**2 + 2*\alpha**4*\beta_2*\beta_3*\kappa_2*\mu*c**2 - \alpha**4*\beta_2*\beta_3*\mu*\omega**3*c**4 + sqrt(3)*I*\alpha**4*\beta_2*\beta_3*\mu*\omega**3*c**4/3 + 2*\alpha**4*\beta_2*\beta_3*\mu*\omega*c**2 - 2*sqrt(3)*I*\alpha**4*\beta_2*\beta_3*\mu*\omega*c**2/3 + \alpha**4*\beta_2*\kappa_2*\kappa_3*\mu*c**2 + sqrt(3)*I*\alpha**4*\beta_2*\kappa_2*\kappa_3*\mu*c**2 - \alpha**4*\beta_2*\kappa_3*\mu*\omega**3*c**4/2 - sqrt(3)*I*\alpha**4*\beta_2*\kappa_3*\mu*\omega**3*c**4/6 + \alpha**4*\beta_2*\kappa_3*\mu*\omega*c**2 + sqrt(3)*I*\alpha**4*\beta_2*\kappa_3*\mu*\omega*c**2/3 + \alpha**4*\beta_3**2*\kappa_1*\mu*c**2 + \alpha**4*\beta_3*\kappa_1*\kappa_3*\mu*c**2 + sqrt(3)*I*\alpha**4*\beta_3*\kappa_1*\kappa_3*\mu*c**2 + \alpha**4*\beta_3*\kappa_2**2*\mu*c**2/2 + sqrt(3)*I*\alpha**4*\beta_3*\kappa_2**2*\mu*c**2/2 - \alpha**4*\beta_3*\kappa_2*\mu*\omega**3*c**4/2 - sqrt(3)*I*\alpha**4*\beta_3*\kappa_2*\mu*\omega**3*c**4/6 + \alpha**4*\beta_3*\kappa_2*\mu*\omega*c**2 + sqrt(3)*I*\alpha**4*\beta_3*\kappa_2*\mu*\omega*c**2/3 + \alpha**4*\beta_3*\mu*\omega**6*c**6/8 + sqrt(3)*I*\alpha**4*\beta_3*\mu*\omega**6*c**6/24 - \alpha**4*\beta_3*\mu*\omega**4*c**4/2 - sqrt(3)*I*\alpha**4*\beta_3*\mu*\omega**4*c**4/6 + \alpha**4*\beta_3*\mu*\omega**2*c**2/2 + sqrt(3)*I*\alpha**4*\beta_3*\mu*\omega**2*c**2/6 - 3*\alpha**4*\kappa_1*\kappa_3**2*\mu*c**2/2 + sqrt(3)*I*\alpha**4*\kappa_1*\kappa_3**2*\mu*c**2/2 - 3*\alpha**4*\kappa_2**2*\kappa_3*\mu*c**2/2 + sqrt(3)*I*\alpha**4*\kappa_2**2*\kappa_3*\mu*c**2/2 - 2*sqrt(3)*I*\alpha**4*\kappa_2*\kappa_3*\mu*\omega**3*c**4/3 + 4*sqrt(3)*I*\alpha**4*\kappa_2*\kappa_3*\mu*\omega*c**2/3 + \alpha**4*\kappa_3*\mu*\omega**6*c**6/8 + sqrt(3)*I*\alpha**4*\kappa_3*\mu*\omega**6*c**6/24 - \alpha**4*\kappa_3*\mu*\omega**4*c**4/2 - sqrt(3)*I*\alpha**4*\kappa_3*\mu*\omega**4*c**4/6 + \alpha**4*\kappa_3*\mu*\omega**2*c**2/2 + sqrt(3)*I*\alpha**4*\kappa_3*\mu*\omega**2*c**2/6 - 2*sqrt(3)*I*\alpha**3*\beta_1*\beta_2*\beta_3*\mu*c**3 + 2*\alpha**3*\beta_1*\beta_2*\kappa_3*\mu*c**3 + 2*\alpha**3*\beta_1*\beta_3*\kappa_2*\mu*c**3 - \alpha**3*\beta_1*\beta_3*\mu*\omega**3*c**5 + sqrt(3)*I*\alpha**3*\beta_1*\beta_3*\mu*\omega**3*c**5/3 + 2*\alpha**3*\beta_1*\beta_3*\mu*\omega*c**3 - 2*sqrt(3)*I*\alpha**3*\beta_1*\beta_3*\mu*\omega*c**3/3 + \alpha**3*\beta_1*\kappa_2*\kappa_3*\mu*c**3 + sqrt(3)*I*\alpha**3*\beta_1*\kappa_2*\kappa_3*\mu*c**3 - \alpha**3*\beta_1*\kappa_3*\mu*\omega**3*c**5/2 - sqrt(3)*I*\alpha**3*\beta_1*\kappa_3*\mu*\omega**3*c**5/6 + \alpha**3*\beta_1*\kappa_3*\mu*\omega*c**3 + sqrt(3)*I*\alpha**3*\beta_1*\kappa_3*\mu*\om ...
# [        -\alpha**6*\beta_3**3*\mu/2 - sqrt(3)*I*\alpha**6*\beta_3**3*\mu/6 + \alpha**6*\beta_3**2*\kappa_3*\mu/2 - sqrt(3)*I*\alpha**6*\beta_3**2*\kappa_3*\mu/2 + \alpha**6*\beta_3*\kappa_3**2*\mu + sqrt(3)*I*\alpha**6*\kappa_3**3*\mu/3 - 3*\alpha**5*\beta_2*\beta_3**2*\mu*c/2 - sqrt(3)*I*\alpha**5*\beta_2*\beta_3**2*\mu*c/2 + \alpha**5*\beta_2*\beta_3*\kappa_3*\mu*c - sqrt(3)*I*\alpha**5*\beta_2*\beta_3*\kappa_3*\mu*c + \alpha**5*\beta_2*\kappa_3**2*\mu*c + \alpha**5*\beta_3**2*\kappa_2*\mu*c/2 - sqrt(3)*I*\alpha**5*\beta_3**2*\kappa_2*\mu*c/2 + sqrt(3)*I*\alpha**5*\beta_3**2*\mu*\omega**3*c**3/3 - 2*sqrt(3)*I*\alpha**5*\beta_3**2*\mu*\omega*c/3 + 2*\alpha**5*\beta_3*\kappa_2*\kappa_3*\mu*c - \alpha**5*\beta_3*\kappa_3*\mu*\omega**3*c**3/2 + sqrt(3)*I*\alpha**5*\beta_3*\kappa_3*\mu*\omega**3*c**3/6 + \alpha**5*\beta_3*\kappa_3*\mu*\omega*c - sqrt(3)*I*\alpha**5*\beta_3*\kappa_3*\mu*\omega*c/3 + sqrt(3)*I*\alpha**5*\kappa_2*\kappa_3**2*\mu*c - \alpha**5*\kappa_3**2*\mu*\omega**3*c**3/2 - sqrt(3)*I*\alpha**5*\kappa_3**2*\mu*\omega**3*c**3/6 + \alpha**5*\kappa_3**2*\mu*\omega*c + sqrt(3)*I*\alpha**5*\kappa_3**2*\mu*\omega*c/3 - 3*\alpha**4*\beta_1*\beta_3**2*\mu*c**2/2 - sqrt(3)*I*\alpha**4*\beta_1*\beta_3**2*\mu*c**2/2 + \alpha**4*\beta_1*\beta_3*\kappa_3*\mu*c**2 - sqrt(3)*I*\alpha**4*\beta_1*\beta_3*\kappa_3*\mu*c**2 + \alpha**4*\beta_1*\kappa_3**2*\mu*c**2 - 3*\alpha**4*\beta_2**2*\beta_3*\mu*c**2/2 - sqrt(3)*I*\alpha**4*\beta_2**2*\beta_3*\mu*c**2/2 + \alpha**4*\beta_2**2*\kappa_3*\mu*c**2/2 - sqrt(3)*I*\alpha**4*\beta_2**2*\kappa_3*\mu*c**2/2 + \alpha**4*\beta_2*\beta_3*\kappa_2*\mu*c**2 - sqrt(3)*I*\alpha**4*\beta_2*\beta_3*\kappa_2*\mu*c**2 + 2*sqrt(3)*I*\alpha**4*\beta_2*\beta_3*\mu*\omega**3*c**4/3 - 4*sqrt(3)*I*\alpha**4*\beta_2*\beta_3*\mu*\omega*c**2/3 + 2*\alpha**4*\beta_2*\kappa_2*\kappa_3*\mu*c**2 - \alpha**4*\beta_2*\kappa_3*\mu*\omega**3*c**4/2 + sqrt(3)*I*\alpha**4*\beta_2*\kappa_3*\mu*\omega**3*c**4/6 + \alpha**4*\beta_2*\kappa_3*\mu*\omega*c**2 - sqrt(3)*I*\alpha**4*\beta_2*\kappa_3*\mu*\omega*c**2/3 + \alpha**4*\beta_3**2*\kappa_1*\mu*c**2/2 - sqrt(3)*I*\alpha**4*\beta_3**2*\kappa_1*\mu*c**2/2 + 2*\alpha**4*\beta_3*\kappa_1*\kappa_3*\mu*c**2 + \alpha**4*\beta_3*\kappa_2**2*\mu*c**2 - \alpha**4*\beta_3*\kappa_2*\mu*\omega**3*c**4/2 + sqrt(3)*I*\alpha**4*\beta_3*\kappa_2*\mu*\omega**3*c**4/6 + \alpha**4*\beta_3*\kappa_2*\mu*\omega*c**2 - sqrt(3)*I*\alpha**4*\beta_3*\kappa_2*\mu*\omega*c**2/3 + \alpha**4*\beta_3*\mu*\omega**6*c**6/8 - sqrt(3)*I*\alpha**4*\beta_3*\mu*\omega**6*c**6/24 - \alpha**4*\beta_3*\mu*\omega**4*c**4/2 + sqrt(3)*I*\alpha**4*\beta_3*\mu*\omega**4*c**4/6 + \alpha**4*\beta_3*\mu*\omega**2*c**2/2 - sqrt(3)*I*\alpha**4*\beta_3*\mu*\omega**2*c**2/6 + sqrt(3)*I*\alpha**4*\kappa_1*\kappa_3**2*\mu*c**2 + sqrt(3)*I*\alpha**4*\kappa_2**2*\kappa_3*\mu*c**2 - \alpha**4*\kappa_2*\kappa_3*\mu*\omega**3*c**4 - sqrt(3)*I*\alpha**4*\kappa_2*\kappa_3*\mu*\omega**3*c**4/3 + 2*\alpha**4*\kappa_2*\kappa_3*\mu*\omega*c**2 + 2*sqrt(3)*I*\alpha**4*\kappa_2*\kappa_3*\mu*\omega*c**2/3 + \alpha**4*\kappa_3*\mu*\omega**6*c**6/8 - sqrt(3)*I*\alpha**4*\kappa_3*\mu*\omega**6*c**6/24 - \alpha**4*\kappa_3*\mu*\omega**4*c**4/2 + sqrt(3)*I*\alpha**4*\kappa_3*\mu*\omega**4*c**4/6 + \alpha**4*\kappa_3*\mu*\omega**2*c**2/2 - sqrt(3)*I*\alpha**4*\kappa_3*\mu*\omega**2*c**2/6 - 3*\alpha**3*\beta_1*\beta_2*\beta_3*\mu*c**3 - sqrt(3)*I*\alpha**3*\beta_1*\beta_2*\beta_3*\mu*c**3 + \alpha**3*\beta_1*\beta_2*\kappa_3*\mu*c**3 - sqrt(3)*I*\alpha**3*\beta_1*\beta_2*\kappa_3*\mu*c**3 + \alpha**3*\beta_1*\beta_3*\kappa_2*\mu*c**3 - sqrt(3)*I*\alpha**3*\beta_1*\beta_3*\kappa_2*\mu*c**3 + 2*sqrt(3)*I*\alpha**3*\beta_1*\beta_3*\mu*\omega**3*c**5/3 - 4*sqrt(3)*I*\alpha**3*\beta_1*\beta_3*\mu*\omega*c**3/3 + 2*\alpha**3*\beta_1*\kappa_2*\kappa_3*\mu*c**3 - \alpha**3*\beta_1*\kappa_3*\mu*\omega**3*c**5/2 + sqrt(3)*I*\alpha**3*\beta_1*\kappa_3*\mu*\omega**3*c**5/6 + \alpha**3*\beta_1*\kappa_3*\mu*\omega*c**3 - sqrt(3)*I*\alpha**3*\beta_1*\kapp ...

# %%
N1 = N[0]
N2 = N[1]

# %%
N1_c_pow2   = N1.coeff(c,2).coeff(alp,0)
N1_c_pow1   = N1.coeff(c,1).coeff(alp,0)
N1_c_alp    = N1.coeff(c,1).coeff(alp,1)
N1_alp_pow1 = N1.coeff(c,0).coeff(alp,1)
N1_alp_pow2 = N1.coeff(c,0).coeff(alp,2)

N2_c_pow2   = N2.coeff(c,2).coeff(alp,0)
N2_c_pow1   = N2.coeff(c,1).coeff(alp,0)
N2_c_alp    = N2.coeff(c,1).coeff(alp,1)
N2_alp_pow1 = N2.coeff(c,0).coeff(alp,1)
N2_alp_pow2 = N2.coeff(c,0).coeff(alp,2)

# %%
N1_c_pow1
# Out:
# 2*\kappa_1

# %%
N2_c_pow1
# Out:
# 2*\beta_1

# %%
N1_alp_pow1
# Out:
# \kappa_2 - sqrt(3)*I*\omega/3

# %%
N2_alp_pow1
# Out:
# \beta_2 + sqrt(3)*I*\omega/3

# %%
k2_sub = smp.solve(N1_alp_pow1,k2)[0]
b2_sub = smp.solve(N2_alp_pow1,b2)[0]

# %%
N1_c_pow2.subs([[b1,0],[k1,0]])
# Out:
# 0

# %%
N1_c_alp = N1_c_alp.subs([[b1,0],[k1,0],[k2,k2_sub],[b2,b2_sub]])
N1_c_alp
# Out:
# -\omega/2 - sqrt(3)*I*\omega/6

# %%
N1_alp_pow2 = N1_alp_pow2.subs([[b1,0],[k1,0],[k2,k2_sub],[b2,b2_sub]])
N1_alp_pow2
# Out:
# -\beta_3*\mu/2 - sqrt(3)*I*\beta_3*\mu/6 + \beta_3/2 + sqrt(3)*I*\beta_3/6 - \kappa_3*\mu/2 - sqrt(3)*I*\kappa_3*\mu/6 + 2*sqrt(3)*I*\kappa_3/3

# %%
N2_c_pow2 = N2_c_pow2.subs([[b1,0],[k1,0],[k2,k2_sub],[b2,b2_sub]])
N2_c_pow2
# Out:
# 0

# %%
N2_c_alp = N2_c_alp.subs([[b1,0],[k1,0],[k2,k2_sub],[b2,b2_sub]])
N2_c_alp
# Out:
# -\omega/2 + sqrt(3)*I*\omega/6

# %%
N2_alp_pow2 = N2_alp_pow2.subs([[b1,0],[k1,0],[k2,k2_sub],[b2,b2_sub]])
N2_alp_pow2
# Out:
# -\beta_3*\mu/2 + sqrt(3)*I*\beta_3*\mu/6 - \beta_3*\mu*(-sqrt(3)*\mu + 3*I*\mu + sqrt(3) - 3*I)/(2*(sqrt(3)*\mu - 3*I*\mu - 4*sqrt(3))) + sqrt(3)*I*\beta_3*\mu*(-sqrt(3)*\mu + 3*I*\mu + sqrt(3) - 3*I)/(6*(sqrt(3)*\mu - 3*I*\mu - 4*sqrt(3))) - 2*sqrt(3)*I*\beta_3/3 + \beta_3*(-sqrt(3)*\mu + 3*I*\mu + sqrt(3) - 3*I)/(2*(sqrt(3)*\mu - 3*I*\mu - 4*sqrt(3))) - sqrt(3)*I*\beta_3*(-sqrt(3)*\mu + 3*I*\mu + sqrt(3) - 3*I)/(6*(sqrt(3)*\mu - 3*I*\mu - 4*sqrt(3)))

# %%
smp.solve([N1_alp_pow2,N2_alp_pow2],[k3,b3])
# Out:
# {\beta_3: 0, \kappa_3: 0}

# %%
smp.solve([N1_c_alp,N2_c_alp],[w])
# Out:
# {\omega: 0}

# %%
N2.subs([[k1,0],
        [k2,0],
        [k3,0]])
# Out:
# -1

# %%
dx1_f = smp.lambdify([x1,x2,t,mu,alp,w],dx1)
dx2_f = smp.lambdify([x1,x2,t,mu,alp,w],dx2)

# %%
x1v = np.linspace(-10,10,20)/2
x2v = np.linspace(-10,10,20)/2

x1G, x2G = np.meshgrid(x1v,x2v)

# %%
mu_val = 1
w_val = 1.2
a_val = 0
F_val = np.linspace(0,1,25)
t_val = np.linspace(0,10*np.pi,1000)

# %% [markdown]
# ## Numerical solution

# %%
from scipy.integrate import odeint
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from ipywidgets import interact

# %%
clr = ['cornflowerblue',
      'gold',
      'tomato',
      'dimgray']

# %% [markdown]
# Eigenvalue pair
#
# $$\frac{\mu}{2} \pm \frac{\sqrt{(\mu - 2)*(\mu + 2)}}{2}$$
#
# When $\mu=1$
#
# $$\frac{1}{2} \pm \frac{\sqrt{3}}{2}\mathcal{i}$$

# %%
class vanDerPol:
    
    clr = ['cornflowerblue',
      'gold',
      'tomato',
      'dimgray']
    
    def __init__(self, mu, Af, wf):
        self.mu = mu
        self.Af = Af
        self.wf = wf
        self.soln = None
        self.T = None
        self.limC = None

    def drive(self,t):
        return self.Af*np.sin(self.wf*t)
    def dif_Eq(self,X,t):
        x1, x2 = X

        dx1 = x2
        dx2 = self.mu*x2*(1-x1**2)-x1 + self.drive(t) #self.Af*np.sin(self.wf*t)

        return [dx1,dx2]

    
    
    def simulate(self,x0,t):
        S = odeint(self.dif_Eq,x0,t).T
        self.soln = [S,t]
        # return self.soln



    def get_limCycle(self,plot =False):
        x, y = self.soln[0]
        t = self.soln[1]
        
        dx = np.diff(x)
        idx = np.where(dx<=0)[0]
        jump = np.where(np.diff(idx)>1)[0]
        idx = idx[jump+1]
        theta0 = idx[-3]
        thetaf = idx[-2]
        self.T = t[thetaf] - t[theta0]
        self.limC = [x[theta0:thetaf],y[theta0:thetaf]]

        if plot ==True:
            plt.plot(self.limC[0],self.limC[1])
            plt.grid()
            plt.title(f'Limit Cycle, with period: {np.round(self.T,3)}')

        
    def plt_sim(self):
        x, y = self.soln[0]
        t = self.soln[1]
            
        fig = plt.figure(figsize=(14,6))
        
        gs = gridspec.GridSpec(1,4)
        
        p1 = fig.add_subplot(gs[:3])
        p2 = fig.add_subplot(gs[3:])
        
        
        p1.plot(t,x,color=clr[0],label=r'$\dot x_1$')
        p1.plot(t,y,color=clr[1],label=r'$\dot x_2$')
        p1.plot(t,self.drive(t),color=clr[2],label=r'$F(t)$')
        p1.grid()
        # p1.plot(self.t,kick(t,kick_time[0],0),color=clr[-1],label=r'$\delta(t)$')
        
        
        
        p1.legend()
        
        p2.plot(x,y)
        p2.grid()
        # p2.set_xlim([1.8,2.1])
        # p2.set_ylim([-0.5,0.5])
        # p2.vlines(0,ymin=ylim[0],ymax=ylim[1],color=clr[-1],linestyle='--')

# %%
vdp_A0 = vanDerPol(1,0,0)

# %%
t = np.linspace(0,100,100000)
x0 = [-0.01,-0.01]
vdp_A0.simulate(x0,t)
vdp_A0.plt_sim()

# %%
vdp_A0.get_limCycle(plot=True)

# %%
x, y = vdp_A0.soln[0]
t = vdp_A0.soln[1]
T = vdp_A0.T

dy = np.diff(y)
idx = np.where(dy<=0)[0]
jump = np.where(np.diff(idx)>1)[0]
idx = idx[jump+1]
x_map = x[idx]
y_map = y[idx]
t_map = t[idx]


plt.scatter(t_map%(T),y_map)
plt.show()

# %%
t = np.linspace(0,10*vdp_A0.T,10000)
SS = vdp_A0.limC

# %%
SS = [vdp_A0.limC[0][-1],
      vdp_A0.limC[1][-1]]

# %%
vdp_A0.simulate(SS,t)
vdp_A0.plt_sim()

# %%
vdp_A03 = vanDerPol(mu = 1,
                    Af = 0.3,
                    wf = 1.2)

# %%
t = np.linspace(0,80,1000)
x0 = [-1,0]

vdp_A03.simulate(x0,t)
vdp_A03.plt_sim()

# %%
vdp_A03.get_limCycle(plot=True)

# %%
x,y = vdp_A03.soln[0]
x0 = [x[-1],y[-1]]

# %%
t = np.linspace(0,10*vdp_A03.T,1000)


vdp_A03.simulate(x0,t)
vdp_A03.plt_sim()

# %%
x, y = vdp_A03.soln[0]
t = vdp_A03.soln[1]
T = vdp_A03.T

dy = np.diff(y)
idx = np.where(dy<=0)[0]
jump = np.where(np.diff(idx)>1)[0]
idx = idx[jump+1]
x_map = x[idx]
y_map = y[idx]
t_map = t[idx]

mod = T/(2*np.pi)

plt.scatter(t_map%1.2,y_map)

# %%
test = y**2


diff = np.diff(test)
idx = np.where(diff>=0)[0]
gap = np.where(np.diff(idx)>1)[0]
idx = idx[gap]

x_pha = []
y_pha = []
t_pha = []
for i in range(gap.size-1):
    x_pha.append(x[idx[i]:idx[i+1]-1])
    y_pha.append(y[idx[i]:idx[i+1]-1])
    t_pha.append(t[idx[i]:idx[i+1]-1])



x_map = x[idx]
y_map = y[idx]
t_map = t[idx]

# %%
plt.plot(test)
plt.plot(np.diff(test))

# %%
fig = plt.figure(figsize=(14,6))

gs = gridspec.GridSpec(1,4)

p1 = fig.add_subplot(gs[:3])
p2 = fig.add_subplot(gs[3:])


p1.plot(t,x,color=clr[0],label=r'$\dot x_1$')
p1.plot(t,y,color=clr[1],label=r'$\dot x_2$')

p1.scatter(t_map,x_map)
p1.scatter(t_map,y_map)
p1.grid()



p1.legend()

p2.scatter(x,y)
p2.scatter(x_map,y_map)
p2.grid()
# p2.set_xlim([1.8,2.1])
# p2.set_ylim([-0.5,0.5])
# p2.vlines(0,ymin=ylim[0],ymax=ylim[1],color=clr[-1],linestyle='--')

# %% [markdown]
# ### Adjoint

# %% [markdown]
# # Duffing Oscillator
#
# Unforced, undamped
#
# $$\ddot{x} - x + x^3 =0$$
#
# When linearized
#
# $$\begin{cases}\dot x_1 = x_2\\
# \dot x_2 = x_1 - x_1^3 - \delta x_2\end{cases}$$
#
# Modified equation [[ch 4, Wiggins]]
#
# $$\begin{cases}\dot x_1 = x_2\\
# \dot x_2 = x_1 - x_1^3 - \delta x_2 + x_1^2x_2\end{cases}$$

# %% [markdown]
# Define symbolic system

# %%
x1, x2, dta, w, t, alp, F = smp.symbols(r'x_1 x_2 \delta \omega t \alpha \mathcal{F}')

dx1 = x2
dx2 = x1 - x1**3 - dta*x2 + alp*(F) + x1**2*x2

# %%
sin = (w*t) - (w*t)**3/(3*2) + (w*t)**5/(5*4*3*2) - (w*t)**7/(7*6*5*4*3*2)

# %%
dx2 = dx2.subs(F,sin)

# %% [markdown]
# ### Check Zeros

# %%
# fix_pnts = smp.solve([dx1,dx2],[x1,x2])
# fix_pnts

# %% [markdown]
# ### Jac-ob

# %%
Jac = smp.Matrix([[smp.diff(dx1,x1),smp.diff(dx1,x2),smp.diff(dx1,t)],
                  [smp.diff(dx2,x1),smp.diff(dx2,x2),smp.diff(dx2,t)],
                  [smp.diff(dt,x1),smp.diff(dt,x2),smp.diff(dt,t)]])
Jac
# Out:
# Matrix([
# [                        0,                1,                                                                            0],
# [-3*x_1**2 + 2*x_1*x_2 + 1, -\delta + x_1**2, \alpha*(-\omega**7*t**6/720 + \omega**5*t**4/24 - \omega**3*t**2/2 + \omega)],
# [                        0,                0,                                                                            0]])

# %%
J0 = Jac.subs([[x1,0],[x2,0],[dta,0]])
J0
# Out:
# Matrix([
# [0, 1,                                                                            0],
# [1, 0, \alpha*(-\omega**7*t**6/720 + \omega**5*t**4/24 - \omega**3*t**2/2 + \omega)],
# [0, 0,                                                                            0]])

# %%
J0.eigenvects()
# Out:
# [(-1,
#   1,
#   [Matrix([
#    [-1],
#    [ 1],
#    [ 0]])]),
#  (0,
#   1,
#   [Matrix([
#    [\alpha*\omega**7*t**6/720 - \alpha*\omega**5*t**4/24 + \alpha*\omega**3*t**2/2 - \alpha*\omega],
#    [                                                                                             0],
#    [                                                                                             1]])]),
#  (1,
#   1,
#   [Matrix([
#    [1],
#    [1],
#    [0]])])]

# %%
ev1 = J0.eigenvects()[1][2][0]
ev2 = J0.eigenvects()[0][2][0]
ev3 = J0.eigenvects()[2][2][0]

# %%
c, s, u = smp.symbols(r'c s u')

csu = smp.Matrix([c,s,u])
xxt = smp.Matrix([x1,x2,t])
P = smp.Matrix([[ev1.T],
                [ev2.T],
                [ev3.T]]).T
Pinv = P.inv()

# %%
trans = P@csu
trans
# Out:
# Matrix([
# [c*(\alpha*\omega**7*t**6/720 - \alpha*\omega**5*t**4/24 + \alpha*\omega**3*t**2/2 - \alpha*\omega) - s + u],
# [                                                                                                     s + u],
# [                                                                                                         c]])

# %%
csu_dot = Pinv@xxt.subs([[x1,dx1],[x2,dx2],[t,dt]])
csu_dot
# Out:
# Matrix([
# [                                                                                                                                                                                                            1],
# [                                                                                                            \alpha*\omega**7*t**6/1440 - \alpha*\omega**5*t**4/48 + \alpha*\omega**3*t**2/4 - \alpha*\omega/2],
# [-\alpha*\omega**7*t**6/1440 + \alpha*\omega**5*t**4/48 - \alpha*\omega**3*t**2/4 + \alpha*\omega/2 + \alpha*(-\omega**7/5040 + \omega**5/120 - \omega**3/6 + \omega) - \delta*x_2 - x_1**3 + x_1**2*x_2 + x_1]])

# %%
csu_dot = csu_dot.subs([[x1,trans[0]],
                        [x2,trans[1]],
                        [t,trans[2]]])
csu_dot
# Out:
# Matrix([
# [                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             1],
# [                                                                                                                                                                                                                                                                                                                                                                                                                                             \alpha*\omega**7*c**6/1440 - \alpha*\omega**5*c**4/48 + \alpha*\omega**3*c**2/4 - \alpha*\omega/2],
# [-\alpha*\omega**7*c**6/1440 + \alpha*\omega**5*c**4/48 - \alpha*\omega**3*c**2/4 + \alpha*\omega/2 + \alpha*(-\omega**7/5040 + \omega**5/120 - \omega**3/6 + \omega) - \delta*(s + u) + c*(\alpha*\omega**7*c**6/720 - \alpha*\omega**5*c**4/24 + \alpha*\omega**3*c**2/2 - \alpha*\omega) - s + u + (s + u)*(c*(\alpha*\omega**7*c**6/720 - \alpha*\omega**5*c**4/24 + \alpha*\omega**3*c**2/2 - \alpha*\omega) - s + u)**2 - (c*(\alpha*\omega**7*c**6/720 - \alpha*\omega**5*c**4/24 + \alpha*\omega**3*c**2/2 - \alpha*\omega) - s + u)**3]])

# %%
dc = csu_dot[0].expand()
ds = csu_dot[1].expand()
du = csu_dot[2].expand()

# %%
A = dc.coeff(c,1).coeff(s,0).coeff(u,0)
g1 = A - dc*c

# %%
Bs = ds.coeff(c,0).coeff(s,1).coeff(u,0)
g2s = Bs - ds*s

# %%
Bu = du.coeff(c,0).coeff(s,0).coeff(u,1)
g2u = Bu - du*u

# %%
B = smp.Matrix([[Bs,0],[0,Bu]])
g2 = smp.Matrix([[g2s],[g2u]])
B
# Out:
# Matrix([
# [0,          0],
# [0, 1 - \delta]])

# %%
k1, k2, k3, k4, k5, k6 = smp.symbols(r'\kappa_1 \kappa_2 \kappa_3 \kappa_4 \kappa_5 \kappa_6')

h = k1*c**2 + k2*c**3

# %%
# Out:
# \kappa_1
